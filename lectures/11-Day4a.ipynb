# %% [markdown]
# # Day 4, Plotting

# %%
import matplotlib.pyplot as plt,os,time;import numpy as np; import pandas as pd
def sho(img,figsize=(12,6)):
    fig,ax=plt.subplots(figsize=figsize)
    img=plt.imread(img)
    ax.imshow(img)
    ax.axis('off')
# %matplotlib inline

# %% [markdown]
# ## Homework

# %% [markdown]
# Use Pandas read_csv for all!
#
# Read and plot (with labels) the data in "sinc.dat". The column names contain the with of the scaling factor and shall be read automatically. Use the x-value as index.
# Read and plot (with labels) the data in "sinc_2.dat". The column names contain the with of the scaling factor and shall be read automatically. Use the x-value as index.
#
#
# The data file "APS_Copper_SolarCell.dat"  was measured at the "Advanced light source" in Chicago and represents X-ray absorption data.
# Read all columns from the file ignoring the headers and use copy paste to extract the column names from the text file and to name the columns the right name. Column "Energy" shall be used as index. Plot column "PR"vs "Energy" Hint, after pasting the column names into the notebook you will have to do a string operation on it.
#
# Read only columns "Energy" and  "PR" from the data file ignoring the headers and use copy paste to extract the column names from the text file and to name the columns the right name. Use column "Energy" as index. (hint the index column number is now the number in the new list, so if you only read 2 columns than either the "0" or the "1".
#
# Advanced:Read in this file and retrieve the column names automatically.

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(10,4))
filen=os.sep.join(('data','sinc.dat'))
df=pd.read_csv(filen,sep=',',index_col=0)
df.plot(ax=ax1)
filen=os.sep.join(('data','sinc_2.dat'))
df2=pd.read_csv(filen,sep='\t',index_col=0)
df2.plot(ax=ax2)

# %%
col_names='N  Epoch  Energy  k  Mono  Seconds  ion1  ion2  ion3  ion4  mud  mud1  mostabc  SYNM  PR  bun-1  bun-1GS  bun1  bun1GS  bun2  bun2GS  DifSYN  Difb_1  Difb1  Difb2  c0o0b0  c0o1b0  c0o2b0  c0o3b0  c0o4b0  c0o5b0  c0o6b0  c0o7b0  c0o8b0  c0o9b0  c0o10b0  c0o11b0  c0o12b0  c0o13b0  c0o14b0  c0o15b0  c0o16b0  c0o17b0  c0o18b0  c0o19b0  c0o20b0  c0o21b0  c1o0b0  c1o1b0  c1o2b0  c1o3b0  c1o4b0  c1o5b0  c1o6b0  c1o7b0  c1o8b0  c1o9b0  c1o10b0  c1o11b0  c1o12b0  c1o13b0  c1o14b0  c1o15b0  c1o16b0  c1o17b0  c1o18b0  c1o19b0  c1o20b0  c1o21b0  c2o0b0  c2o1b0  c2o2b0  c2o3b0  c2o4b0  c2o5b0  c2o6b0  c2o7b0  c2o8b0  c2o9b0  c2o10b0  c2o11b0  c2o12b0  c2o13b0  c2o14b0  c2o15b0  c2o16b0  c2o17b0  c2o18b0  c2o19b0  c2o20b0  c2o21b0  c3o0b0  c3o1b0  c3o2b0  c3o3b0  c3o4b0  c3o5b0  c3o6b0  c3o7b0  c3o8b0  c3o9b0  c3o10b0  c3o11b0  c3o12b0  c3o13b0  c3o14b0  c3o15b0  c3o16b0  c3o17b0  c3o18b0  c3o19b0  c3o20b0  c3o21b0'
col_names=col_names.split()
filen=os.sep.join(('data','APS_Copper_SolarCell.dat'))
df3=pd.read_csv(filen,skiprows=30,names=col_names,sep='\s+',index_col=2)
df3.head()
df3.loc[:,'PR'].plot()
df3.PR.plot()

# %%
df3=pd.read_csv(filen,skiprows=30,sep='\s+',names=['Energy','PR'],index_col=0,usecols=[2,14])
df3.plot()

# %%
### Advanced:
df4=pd.read_csv(filen,skiprows=29,escapechar='L',sep='\s+',index_col=0,usecols=[2,14])
df3.plot()

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Matlab style plotting $\leftrightarrow $ Object style plotting

# %% [markdown]
# What does plotting actually mean?
# import matplotlib.pyplot as plt

# %% [markdown]
# [Matplotlib backends](https://matplotlib.org/tutorials/introductory/usage.html#backends)

# %%
plt.ion()
x=np.arange(-5,5,0.01)
plt.plot(x,np.sin(2*np.pi*x))
plt.xlim((-4,4))
fig=plt.gcf() #here we get the "handles to the figure"
ax=plt.gca() #here we get the "handles to the axis"
print('the figure is:',fig)
print('the axis is:',ax)
# Out:
# the figure is: Figure(432x288)
# the axis is: AxesSubplot(0.125,0.125;0.775x0.755)

# %%
### our convention: we use matlab type plotting for quick convenience and the object type for everything else

# %% [markdown]
# What does a plot consist of?

# %%
sho('pictures'+os.sep+'KEMM30_006.png',figsize=(18,12))

# %% [markdown]
# Difference: namespace, syntax, plt.show()

# %%
fig,(ax1,ax2)=plt.subplots(1,2)
fig,ax=plt.subplots(2,1)

# %%
plt.ion()
fig,ax=plt.subplots()
ax.plot(x,np.sin(2*np.pi*x))
print(ax.get_xlim())
ax.set_xlim(-2,2)
plt.show()#
# Out:
# (-5.49949999999999, 5.489499999999777)

# %% [markdown]
# ### Ticks

# %%
a=ax.get_xticks()
print(a)
ax.set_xticklabels(['%.5f'%b for b in a])
fig
# Out:
# [-2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5  2. ]

# %% [markdown]
# ### labels

# %%
fig,ax=plt.subplots()
df4.plot(ax=ax)

# %% [markdown]
# ### Axis labels and legend (shape and position)

# %%
ax.set_xlabel('Energy [keV]')
ax.set_ylabel('Intensity [Norm.]')
leg=ax.legend(frameon=False,loc=4)

# %%
fig,ax=plt.subplots()
df.plot(ax=ax)
handles, labels = ax.get_legend_handles_labels()
print(['handles %s \n'%a for a in handles])
# Out:
# ['handles Line2D(1.0) \n', 'handles Line2D(1.7) \n', 'handles Line2D(11.6) \n', 'handles Line2D(13.7) \n', 'handles Line2D(16.0) \n', 'handles Line2D(18.5) \n', 'handles Line2D(2.6) \n', 'handles Line2D(21.2) \n', 'handles Line2D(24.0) \n', 'handles Line2D(3.6) \n', 'handles Line2D(4.8) \n', 'handles Line2D(6.2) \n', 'handles Line2D(7.8) \n', 'handles Line2D(9.6) \n']

# %% [markdown]
# ### cheat sheets

# %% [markdown]
# How should I ever remember all of this? $\rightarrow$ you get used to it or you look it up/use a cheat sheet
#
# https://python-graph-gallery.com/wp-content/uploads/Matplotlib_cheatsheet_datacamp.png
#
# Or look in the folder Cheat cheats

# %%
handles, labels = ax.get_legend_handles_labels()
leg=ax.legend(handles[::2],labels[::2],frameon=False,fontsize=18,labelspacing=0,ncol=2,columnspacing=0,numpoints=1,handlelength=1)
fig

# %%
import matplotlib
font = {'family' : 'Arial Unicode MS',
    'weight' : 'bold',
    'size'   : 24}
matplotlib.rc('font', **font)
fig,ax=plt.subplots()
ax=df.plot(ax=ax)
ax.legend(fontsize=12)
# Out:
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial Unicode MS'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Tasks

# %% [markdown]
# we want to measure what is the average number of dots shown by a dice and estimate the precission for our guess.

# %% [markdown]
# * use fontsize 18 and make a figure with 16x16 inch size
# * use subplots to make two horizontal plots over the whole width.
# * in the first axis, plot: the experiment done with 100 throws:
#
# * for this we throw the dice using np.random.choice to create a matrix in which each of the 100 rows contains one throw of the dice and each of the 10000 columns contains a new experiment from which we estimate the quality of our guess.
# * the mean over all rows results in a vector with 10000 entries that estimates the average throw of the dice. (use axis keyword in mean)

# %%
# Code here

# %% [markdown]
# * read what np.histogram does, The function returns the "edges" of the bins and the counts in each bin. Why are they of different length? Classically one takes the middle of the bins to create  nice plot. Use clever slicing to create a vector with the middle of the bins
# * create a vector that contains the bins from 0 to 7 in 0.05 steps and calculate the histrogram and catch its two output vectors
# * plot the histogram using a bar plot with grey bars in the first axis.
# * Important you have to adjust the width of the bars to the steps you used to sample the results
# * plot in the same axis a gaussian function with mu=average of all experiments, and is sigma=standard_deviation(with ddof=1) of all experiments. Write one sentence why is this an good representation.
# * label the x- and y scale
# * change the x-axis from 2.5 to 4.5
# * format the x-axis ticks to have precisely 2 after comma digits
# * format the y-axis in scientific notation (using exponents)
# * make a legend in the upper left corner. in the legend write the entries and colors you plotted
# * find a way to add extra text to the legend and write the parameters of the gaussian curve into the legend

# %%
#code here

# %%
sho('task_pictures'+os.sep+'zdice_example.png')
ax=plt.gca()
_=ax.set_title('The final figure will look like this,\n but we have to plot the second axis first')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aeebc351dbef> in <module>
# ----> 1 sho('task_pictures'+os.sep+'zdice_example.png')
#       2 ax=plt.gca()
#       3 _=ax.set_title('The final figure will look like this,\n but we have to plot the second axis first')
#
# NameError: name 'sho' is not defined

# %% [markdown]
# * Add a scatterplot into the second axis where each experiment of 100 throws is a single point. The x-coordinate is the mean of the 100 throws. The y-coordinate is randomly chosen between 0 and the height of the gaussian. (np.random.rand gives [0-1). if you multiply it with the gaussian heigth calculated before you can achieve this effect.
# * use markersize 1 for this plot
# * don't forget to label the axis and make a legend (use bbox_to_anchor to place it somewhere proper)
# * draw a horizontal line in the plot at the heigth representing the maximum of the gaussian curve divided by the contant e
# * what is the difference between variance, standard deviation and standard deviation with ddof=1?
# * Save the resulting figure as png with 250dpi and as svg for further customisation

# %% [markdown]
# Advanced:
# * In this scatterplot, plot all points inside the one sigma environment (=1/2 std diviation) of the mean in blue and all outside in red.
# * hint: you can externally create a "slicing vector" by e.g. a=x>5 and combine multiple of thos with e.g np.all
# * write in the legend in addition to the colour the total number of counts in each group. (hint, use sum on t
